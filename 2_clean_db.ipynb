# %% [markdown]
# # develop and test clean_db.py

# %%
import src.clean_db as cdb
import src.metadata_handler as mdh

# %autoreload 2

# %%
import pandas as pd
import numpy as np

import re

# %%
raw_db = pd.read_json('data/test_DB.json')

# %%
raw_db.head(3).T
# Out:
#                                                  0                          1  \
# by-line                                Cathy Clark                     Picasa
# caption/abstract             M2E32L107-108R390B311                        NaN
# contact                                         []                         []
# copyright notice            Conservation Northwest                        NaN
# date created                           2.01505e+07                        NaN
# file_path              first_sample/EK000004-2.JPG  first_sample/EK000004.JPG
# keywords                            [Camera Check]             [camera check]
# object name                              wolverine                        NaN
# sub-location                Blackjack Ridge-2015-1                        NaN
# supplemental category                           []                         []
# time created                                114952                        NaN
#
#                                                  2
# by-line                                Cathy Clark
# caption/abstract                                 1
# contact                                         []
# copyright notice            Conservation Northwest
# date created                           2.01506e+07
# file_path              first_sample/EK000010-2.JPG
# keywords                            [hoary marmot]
# object name                              wolverine
# sub-location                Blackjack Ridge-2015-1
# supplemental category                           []
# time created                                145440

# %% [markdown]
# # Rename Columns (remove spaces)

# %%
raw_db.columns
# Out:
# Index([u'by-line', u'caption/abstract', u'contact', u'copyright notice',
#        u'date created', u'file_path', u'keywords', u'object name',
#        u'sub-location', u'supplemental category', u'time created'],
#       dtype='object')

# %%
def space_free_col_names(db):
    dd = {}
    for col in db.columns:
        new_col = col
        new_col = new_col.replace(' ', '_')
        new_col = new_col.replace('-', '_')
        new_col = new_col.replace('/', '_')
        if new_col != col:
            dd[col] = new_col
    db = db.rename(columns = dd)
    return db

# %%
db = raw_db

print 'original cols: \n',db.columns

db = space_free_col_names(db)

print 'new cols: \n',db.columns
# Out:
# original cols:
# Index([u'by-line', u'caption/abstract', u'contact', u'copyright notice',
#        u'date created', u'file_path', u'keywords', u'object name',
#        u'sub-location', u'supplemental category', u'time created'],
#       dtype='object')
# new cols:
# Index([u'by_line', u'caption_abstract', u'contact', u'copyright_notice',
#        u'date_created', u'file_path', u'keywords', u'object_name',
#        u'sub_location', u'supplemental_category', u'time_created'],
#       dtype='object')

# %% [markdown]
# # Handle Dates and Times

# %%
# change type of entries in date_created to int?

# %%
def _fix_date(date):
    # remove decimal?
    date = str(date)
    if date == 'nan':
        return 'NaN'
    else:
        return re.sub('(....)(..)(..)(..)', '\\1-\\2-\\3', date)

fix_date = np.vectorize(_fix_date)

# %%
db.date_created = fix_date(db.date_created)
db.head(3).T
# Out:
#                                                  0                          1  \
# by_line                                Cathy Clark                     Picasa
# caption_abstract             M2E32L107-108R390B311                        NaN
# contact                                         []                         []
# copyright_notice            Conservation Northwest                        NaN
# date_created                            2015-05-30                        NaN
# file_path              first_sample/EK000004-2.JPG  first_sample/EK000004.JPG
# keywords                            [Camera Check]             [camera check]
# object_name                              wolverine                        NaN
# sub_location                Blackjack Ridge-2015-1                        NaN
# supplemental_category                           []                         []
# time_created                                114952                        NaN
#
#                                                  2
# by_line                                Cathy Clark
# caption_abstract                                 1
# contact                                         []
# copyright_notice            Conservation Northwest
# date_created                            2015-06-04
# file_path              first_sample/EK000010-2.JPG
# keywords                            [hoary marmot]
# object_name                              wolverine
# sub_location                Blackjack Ridge-2015-1
# supplemental_category                           []
# time_created                                145440

# %%
def _fix_time(time):
    # remove decimal?
    time = str(time)
    if time == 'nan':
        return None
    elif len(time) == 7:
        return re.sub('(.)(..)(..)(..)', '\\1:\\2:\\3', time)
    else:
        return re.sub('(..)(..)(..)(..)', '\\1:\\2:\\3', time)

fix_time = np.vectorize(_fix_time)

# %%
fix_time(db.time_created)
# Out:
# array(['11:49:52', 'None', '14:54:40', 'None', '2:54:40', 'None',
#        '2:54:41', 'None', '2:54:46', 'None', '19:56:03', 'None', '7:04:24',
#        'None', '19:04:25', 'None', '19:04:26', 'None', '19:04:29', 'None',
#        '19:04:30', 'None', '19:04:30', 'None', '19:04:25', 'None',
#        '19:04:26', 'None', '19:04:29', 'None', '19:04:30', 'None',
#        '19:04:30', 'None'],
#       dtype='|S8')

# %% [markdown]
# # Handle null values
# ## (and Clean Obvious Duplicates?)

# %% [markdown]
# THOUGHTS:
#
# drop anything where
# + ? improper/nonexistent keywords
# + ? by_line: Picasa (or similar)
# + ? by_line NOT person name
# + ? object / copyright / sub_loc == NaN

# %%
db[['caption_abstract', 'file_path', 'keywords']]
# Out:
#          caption_abstract                                   file_path  \
# 0   M2E32L107-108R390B311                 first_sample/EK000004-2.JPG
# 1                     NaN                   first_sample/EK000004.JPG
# 2                       1                 first_sample/EK000010-2.JPG
# 3                     NaN                   first_sample/EK000010.JPG
# 4                       1                 first_sample/EK000011-2.JPG
# 5                     NaN                   first_sample/EK000011.JPG
# 6                       1                 first_sample/EK000012-2.JPG
# 7                     NaN                   first_sample/EK000012.JPG
# 8                       1                 first_sample/EK000013-2.JPG
# 9                     NaN                   first_sample/EK000013.JPG
# 10    M2E19L73-73R396B305                 first_sample/EK000016-2.JPG
# 11                    NaN                   first_sample/EK000016.JPG
# 12                      1                 first_sample/EK000025-2.JPG
# 13                    NaN                   first_sample/EK000025.JPG
# 14                      1                 first_sample/EK000026-2.JPG
# 15                    NaN                   first_sample/EK000026.JPG
# 16                      1                 first_sample/EK000027-2.JPG
# 17                    NaN                   first_sample/EK000027.JPG
# 18                      1                 first_sample/EK000028-2.JPG
# 19                    NaN                   first_sample/EK000028.JPG
# 20    M2E15L62-62R384B307                 first_sample/EK000029-2.JPG
# 21                    NaN                   first_sample/EK000029.JPG
# 22    M2E15L62-62R384B307                 first_sample/EK000030-2.JPG
# 23                    NaN                   first_sample/EK000030.JPG
# 24                      1  first_sample/test_subfolder/EK000026-2.JPG
# 25                    NaN    first_sample/test_subfolder/EK000026.JPG
# 26                      1  first_sample/test_subfolder/EK000027-2.JPG
# 27                    NaN    first_sample/test_subfolder/EK000027.JPG
# 28                      1  first_sample/test_subfolder/EK000028-2.JPG
# 29                    NaN    first_sample/test_subfolder/EK000028.JPG
# 30    M2E15L62-62R384B307  first_sample/test_subfolder/EK000029-2.JPG
# 31                    NaN    first_sample/test_subfolder/EK000029.JPG
# 32    M2E15L62-62R384B307  first_sample/test_subfolder/EK000030-2.JPG
# 33                    NaN    first_sample/test_subfolder/EK000030.JPG
#
#           keywords
# 0   [Camera Check]
# 1   [camera check]
# 2   [hoary marmot]
# 3         [marmot]
# 4   [hoary marmot]
# 5         [marmot]
# 6   [hoary marmot]
# 7         [marmot]
# 8   [hoary marmot]
# 9         [marmot]
# 10  [unidentified]
# 11              []
# 12     [mule deer]
# 13          [deer]
# 14     [mule deer]
# 15          [deer]
# 16     [mule deer]
# 17          [deer]
# 18     [mule deer]
# 19          [deer]
# 20              []
# 21              []
# 22              []
# 23              []
# 24     [mule deer]
# 25          [deer]
# 26     [mule deer]
# 27          [deer]
# 28     [mule deer]
# 29          [deer]
# 30              []
# 31              []
# 32              []
# 33              []
